# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Copy the the .csv file into your notebook to access the data
df = pd.read_csv("/content/drive/Shared drives/Data Science for Social Good/Week_1/Day_7/University_Diversity_2019.csv")

# %%
df.head()
# people = pd.DataFrame({"age": [23, 25], "hair_color":["light brown", "dark brown"]}, index=["delia", "andrew"])
# Out:
#   Unnamed: 0     Men  ...  Race and/or ethnicity unknown  Total
# 0      Brown  3263.0  ...                          316.0   6834
# 1   Columbia  4548.0  ...                          290.0   9001
# 2    Cornell  6939.0  ...                         1206.0  14976
# 3  Dartmouth  2217.0  ...                           62.0   4365
# 4    Harvard  3389.0  ...                           91.0   6695
#
# [5 rows x 13 columns]

# %%
df.set_index(df['Unnamed: 0'], inplace=True)

# %%
df_reindexed = df.set_index(df['Unnamed: 0'])

# %% [markdown]
# [Drop a column](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
for x in range(len(df.columns[:-1])):
  df["Percent_" + df.columns[x]] = df[df.columns[x]]/df['Total'] 
  print(["created percent_" + df.columns[x] + " column"])
# Out:
# ['created percent_Men column']
# ['created percent_Women column']
# ['created percent_Nonresident Aliens column']
# ['created percent_Hispanic/Latino column']
# ['created percent_Black or African American, non-Hispanic column']
# ['created percent_White, non-Hispanic column']
# ['created percent_American Indian or Alaska Native, non-Hispanic column']
# ['created percent_Asian, non-Hispanic column']
# ['created percent_Native Hawaiian or other Pacific Islander, non-Hispanic column']
# ['created percent_Two or more races, non-Hispanic column']
# ['created percent_Race and/or ethnicity unknown column']

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

x = ['Alien', 'Latino', 'Black', 'White', 'NA', 'Asian', 'PI', 'Two', 'Unknown']
y = df.loc['Harvard', df.columns[14:]]
plt.bar(x, y)
plt.xlabel('Races at Princeton')
plt.ylabel('Percentages')
plt.title('Racial diversity at Princeton')
# Out:
# Text(0.5, 1.0, 'Racial diversity at Princeton')

# %% [markdown]
# [Set index this dataframe](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.set_index.html#pandas.DataFrame.set_index)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

x = ['Alien', 'Latino', 'Black', 'White', 'NA', 'Asian', 'PI', 'Two', 'Unknown']
y = df.loc['Princeton', df.columns[14:]]
plt.bar(x, y)
plt.xlabel('Races at Princeton')
plt.ylabel('Percentages')
plt.title('Racial diversity at Princeton')
# Out:
# Text(0.5, 1.0, 'Racial diversity at Princeton')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

x = ['Alien', 'Latino', 'Black', 'White', 'NA', 'Asian', 'PI', 'Two', 'Unknown']
y = df.loc['Harvard', df.columns[14:]]
plt.bar(x, y)
plt.xlabel('Races at Princeton')
plt.ylabel('Percentages')
plt.title('Racial diversity at Princeton')
# Out:
# Text(0.5, 1.0, 'Racial diversity at Princeton')

# %%
df = df.round(3) * 100

# %%
df.iloc[:, 14:]
# Out:
#             Percent_Nonresident Aliens  ...  Percent_Race and/or ethnicity unknown
# Unnamed: 0                              ...
# Brown                             11.4  ...                                    4.6
# Columbia                          18.7  ...                                    3.2
# Cornell                           10.4  ...                                    8.1
# Dartmouth                          9.8  ...                                    1.4
# Harvard                           12.2  ...                                    1.4
# Princeton                         12.0  ...                                    1.3
# Penn                              13.4  ...                                    2.5
# Yale                              10.2  ...                                    0.5
# USA                                NaN  ...                                    NaN
#
# [9 rows x 9 columns]

# %% [markdown]
# # [Matplotlib](https://matplotlib.org/index.html)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ![alt text](https://matplotlib.org/_images/anatomy.png)

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel('list of numbers')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'ro') # ro: red circles; x-axis, y-axis
plt.axis([0, 6, 0, 20]) # 0-6: x axis; 0-20: y-axis
plt.show()

# %%
import numpy as np

np.arange(0, 5, 0.2)
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8])

# %%
t = np.arange(0, 5, 0.2)
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.title('Evenly samples time at 200 ms intervals')
plt.xlabel('time')
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
df.head()
# Out:
#                  Men  ...  Percent_Race and/or ethnicity unknown
# Unnamed: 0            ...
# Brown       326300.0  ...                                    4.6
# Columbia    454800.0  ...                                    3.2
# Cornell     693900.0  ...                                    8.1
# Dartmouth   221700.0  ...                                    1.4
# Harvard     338900.0  ...                                    1.4
#
# [5 rows x 23 columns]

# %% [markdown]
# Bar Chart: [Resource 1](https://benalexkeen.com/bar-charts-in-matplotlib/), [Resource 2](https://pythonspot.com/matplotlib-bar-chart/)
#
# Display the percentages of men vs women at Princeton University

# %% [markdown]
# Bar Chart: [Resource 1](https://benalexkeen.com/bar-charts-in-matplotlib/), [Resource 2](https://pythonspot.com/matplotlib-bar-chart/)
#
# Display the percentages of each racial category at Princeton University

# %% [markdown]
# [Pie Chart](https://matplotlib.org/3.2.1/gallery/pie_and_polar_charts/pie_features.html)
# 2. Display the percentages of each racial category at Princeton University

# %% [markdown]
# [Pie Chart](https://matplotlib.org/3.2.1/gallery/pie_and_polar_charts/pie_features.html):
# 1. Display the percentages of men vs women at Princeton University

# %% [markdown]
# [Horizontal Bar Chart (more challenging): ](https://matplotlib.org/gallery/lines_bars_and_markers/horizon9tal_barchart_distribution.html?highlight=bar%20chart)
# - Create a horizontal bar chart to display the racial percentages of every university

# %% [markdown]
# [Horizontal Bar Chart (more challenging): ](https://matplotlib.org/gallery/lines_bars_and_markers/horizon9tal_barchart_distribution.html?highlight=bar%20chart)
# - Create a horizontal bar chart to display the gender percentages of every university

# %% [markdown]
# [Interactive Bar Chart](https://plotly.com/python/horizontal-bar-charts/): University Diversity

# %%
import plotly.graph_objects as go

top_labels = list(df.columns[2:-1])
colors = ['rgba(0, 0, 0, 1)', 'rgba(230, 238, 255, 1)', 'rgba(204, 220, 255, 1)', 'rgba(179, 203, 255, 1)', 
          'rgba(128, 168, 255 1)','rgba(77, 133, 255, 1)', 'rgba(26, 98, 255, 1)', 
          'rgba(0, 77, 230, 1)', 'rgba(1, 1, 1, 1)']

x_data = []
for i in range(len(df.index)):
  x_data.append(list(df.iloc[i, 14:].round(3)))

y_data = list(df.index)

fig = go.Figure()

for i in range(0, len(x_data[0])):
    for xd, yd in zip(x_data, y_data):
        fig.add_trace(go.Bar(
            x=[xd[i]], y=[yd],
            orientation='h',
            marker=dict(
                color=colors[i],
                line=dict(color='rgb(248, 248, 249)', width=1)
            )
        ))

fig.update_layout(
    xaxis=dict(
        showgrid=False,
        showline=False,
        showticklabels=False,
        zeroline=False,
        domain=[0.15, 1]
    ),
    yaxis=dict(
        showgrid=False,
        showline=False,
        showticklabels=False,
        zeroline=False,
    ),
    barmode='stack',
    paper_bgcolor='rgb(248, 248, 255)',
    plot_bgcolor='rgb(248, 248, 255)',
    margin=dict(t=80, b=0, l=0, r=0),
    showlegend=False,
)
fig.update_yaxes(automargin=True)
fig.update_xaxes(automargin=True)

annotations = []

for yd, xd in zip(y_data, x_data):
    # labeling the y-axis
    annotations.append(dict(xref='paper', yref='y',
                            x=0.14, y=yd,
                            xanchor='right',
                            text=str(yd),
                            font=dict(family='Arial', size=10,
                                      color='rgb(67, 67, 67)'),
                            showarrow=False, align='right'))
    # labeling the first percentage of each bar (x_axis)
    annotations.append(dict(xref='x', yref='y',
                            x=xd[0] / 2, y=yd,
                            text=str(xd[0]) + '%',
                            font=dict(family='Arial', size=10,
                                      color='rgb(248, 248, 255)'),
                            showarrow=False))
    # labeling the first Likert scale (on the top)
    if yd == y_data[-1]:
        annotations.append(dict(xref='x', yref='paper',
                                x=xd[0] / 2, y=1.1,
                                text=top_labels[0],
                                font=dict(family='Arial', size=10,
                                          color='rgb(67, 67, 67)'),
                                showarrow=False))
    space = xd[0]
    for i in range(1, len(xd)):
            # labeling the rest of percentages for each bar (x_axis)
            annotations.append(dict(xref='x', yref='y',
                                    x=space + (xd[i]/2), y=yd,
                                    text=str(xd[i]) + '%',
                                    font=dict(family='Arial', size=10,
                                              color='rgb(248, 248, 255)'),
                                    showarrow=False))
            # labeling the Likert scale
            if yd == y_data[-1]:
                annotations.append(dict(xref='x', yref='paper',
                                        x=space + (xd[i]/2), y=1.1,
                                        text=top_labels[i],
                                        font=dict(family='Arial', size=10,
                                                  color='rgb(67, 67, 67)'),
                                        showarrow=False))
            space += xd[i]

fig.update_layout(annotations=annotations)
fig.update_layout(title="Racial Diversity in Ivy League Universities",
                  xaxis_title="Demographic Makeup")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dd3056d1-d2a3-478b-a461-ca61ea3d545e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dd3056d1-d2a3-478b-a461-ca61ea3d545e")) {
#                     Plotly.newPlot(
#                         'dd3056d1-d2a3-478b-a461-ca61ea3d545e',
# ...

# %%
import plotly.graph_objects as go

schools = ["Brown", "NYU", "Notre Dame", "Cornell", "Tufts", "Yale",
           "Dartmouth", "Chicago", "Columbia", "Duke", "Georgetown",
           "Princeton", "U.Penn", "Stanford", "MIT", "Harvard"]

fig = go.Figure()
fig.add_trace(go.Scatter(
    x=[72, 67, 73, 80, 76, 79, 84, 78, 86, 93, 94, 90, 92, 96, 94, 112],
    y=schools,
    marker=dict(color="crimson", size=12),
    mode="markers",
    name="Women",
))

fig.add_trace(go.Scatter(
    x=[92, 94, 100, 107, 112, 114, 114, 118, 119, 124, 131, 137, 141, 151, 152, 165],
    y=schools,
    marker=dict(color="gold", size=12),
    mode="markers",
    name="Men",
))

fig.update_layout(title="Gender Earnings Disparity",
                  xaxis_title="Annual Salary (in thousands)",
                  yaxis_title="School")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a855514b-ea80-4732-a7e1-223efa09ab94" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a855514b-ea80-4732-a7e1-223efa09ab94")) {
#                     Plotly.newPlot(
#                         'a855514b-ea80-4732-a7e1-223efa09ab94',
# ...
